# %% [markdown]
# # Projet Data Science 2025-2026
#
# # Sujet projet :
# # Analyse de données et en prévention des risques routiers
#
# Licence 3 SDN, Université Catholique de Lille
#
# Membres du groupe :
# - Issam ATRARI
# - Noé LABBÉ
# - Enzo NZENGUE MAYILA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Chargement des données 
df = pd.read_csv("accidents_2024.csv", sep=";", encoding="latin-1")

# %%
# Aperçu des données 
df.head(20)
# Out:
#      Num_Acc Département       Agglomération  \
# 0   2,02E+11          70  Hors agglomération
# 1   2,02E+11          21    En agglomération
# 2   2,02E+11          15  Hors agglomération
# 3   2,02E+11          14    En agglomération
# 4   2,02E+11          13  Hors agglomération
# 5   2,02E+11          13    En agglomération
# 6   2,02E+11          13    En agglomération
# 7   2,02E+11           7    En agglomération
# 8   2,02E+11           7    En agglomération
# 9   2,02E+11           6    En agglomération
# 10  2,02E+11          75    En agglomération
# 11  2,02E+11          75    En agglomération
# 12  2,02E+11          75    En agglomération
# 13  2,02E+11          75    En agglomération
# 14  2,02E+11          75    En agglomération
# 15  2,02E+11          75    En agglomération
# 16  2,02E+11          75    En agglomération
# 17  2,02E+11          75    En agglomération
# 18  2,02E+11          75    En agglomération
# 19  2,02E+11          94    En agglomération
#
#                            Luminosité Météo (conditions atmos.)  \
# 0                   Crépuscule / aube        Brouillard / fumée
# 1                          Plein jour         Temps éblouissant
# 2                   Crépuscule / aube                   Normale
# 3                          Plein jour         Temps éblouissant
# 4   Nuit avec éclairage public allumé              Pluie légère
# 5   Nuit avec éclairage public allumé                   Normale
# 6   Nuit avec éclairage public allumé                   Normale
# 7                          Plein jour                   Normale
# 8          Nuit sans éclairage public                   Normale
# 9   Nuit avec éclairage public allumé                   Normale
# 10                  Crépuscule / aube                   Normale
# 11         Nuit sans éclairage public                   Normale
# 12                         Plein jour                   Normale
# 13                         Plein jour                   Normale
# 14                         Plein jour                   Normale
# 15                         Plein jour                   Normale
# 16                         Plein jour                   Normale
# 17                         Plein jour                   Normale
# 18                         Plein jour                   Normale
# 19  Nuit avec éclairage public allumé                   Normale
#
#                           Type de collision               Catégorie de route  \
# 0                    2 véhicules - frontale             Route départementale
# 1                           Autre collision                   Voie communale
# 2                           Autre collision                   Voie communale
# 3                 2 véhicules - par le côté                   Voie communale
# 4   3 véhicules et + - collisions multiples                        Autoroute
# 5                 2 véhicules - par le côté                   Voie communale
# 6                 2 véhicules - par le côté  Parking ouvert à la circulation
# 7               2 véhicules - par larrière                   Voie communale
# 8                           Autre collision                   Voie communale
# 9                            Sans collision                   Voie communale
# 10              2 véhicules - par larrière                   Voie communale
# 11                           Sans collision                   Voie communale
# 12                          Autre collision                   Voie communale
# 13                2 véhicules - par le côté                   Voie communale
# 14                   2 véhicules - frontale                   Voie communale
# 15                2 véhicules - par le côté                   Voie communale
# 16                          Autre collision                   Voie communale
# 17                2 véhicules - par le côté                   Voie communale
# 18                          Autre collision                   Voie communale
# 19                   2 véhicules - frontale             Route départementale
#
#    Régime de circulation Nombre de voies  État de la surface  \
# 0       Bidirectionnelle       2 voie(s)             Normale
# 1       Bidirectionnelle       2 voie(s)               Autre
# 2       Bidirectionnelle       2 voie(s)             Normale
# 3       Bidirectionnelle       4 voie(s)             Normale
# 4       Bidirectionnelle       4 voie(s)            Mouillée
# 5       Bidirectionnelle       3 voie(s)             Normale
# 6       Bidirectionnelle       2 voie(s)             Normale
# 7       Bidirectionnelle       2 voie(s)             Normale
# 8       Bidirectionnelle       1 voie(s)             Normale
# 9            Sens unique       2 voie(s)             Normale
# 10           Sens unique       4 voie(s)             Normale
# 11           Sens unique       4 voie(s)  Corps gras / huile
# 12      Bidirectionnelle       2 voie(s)             Normale
# 13           Sens unique       2 voie(s)             Normale
# 14           Sens unique       2 voie(s)             Normale
# 15           Sens unique       2 voie(s)             Normale
# 16           Sens unique       1 voie(s)             Normale
# 17           Sens unique       2 voie(s)             Normale
# 18           Sens unique       3 voie(s)            Mouillée
# 19      Bidirectionnelle       2 voie(s)             Normale
#
#        Infrastructure Situation de laccident Vitesse max autorisée  \
# 0               Aucun            Sur chaussée               90 km/h
# 1               Aucun            Sur chaussée               30 km/h
# 2               Aucun          Sur accotement               50 km/h
# 3              Autres            Sur chaussée               50 km/h
# 4               Aucun            Sur chaussée               50 km/h
# 5   Carrefour aménagé            Sur chaussée               50 km/h
# 6              Autres            Sur chaussée               50 km/h
# 7               Aucun            Sur chaussée               50 km/h
# 8               Aucun          Sur accotement               50 km/h
# 9               Aucun      Sur piste cyclable               50 km/h
# 10              Aucun            Sur chaussée               70 km/h
# 11              Aucun            Sur chaussée               70 km/h
# 12              Aucun            Sur chaussée               30 km/h
# 13              Aucun            Sur chaussée               30 km/h
# 14              Aucun                  Autres               20 km/h
# 15              Aucun      Sur piste cyclable               30 km/h
# 16              Aucun            Sur chaussée               30 km/h
# 17              Aucun            Sur chaussée               50 km/h
# 18              Aucun            Sur chaussée               30 km/h
# 19              Aucun            Sur chaussée               50 km/h
#
#        Gravité (label)
# 0   Blessé hospitalisé
# 1   Blessé hospitalisé
# 2   Blessé hospitalisé
# 3         Blessé léger
# 4         Blessé léger
# 5         Blessé léger
# 6   Blessé hospitalisé
# 7         Blessé léger
# 8         Blessé léger
# 9   Blessé hospitalisé
# 10        Blessé léger
# 11        Blessé léger
# 12        Blessé léger
# 13        Blessé léger
# 14        Blessé léger
# 15        Blessé léger
# 16        Blessé léger
# 17        Blessé léger
# 18        Blessé léger
# 19        Blessé léger

# %%
# Informations du dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54402 entries, 0 to 54401
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Num_Acc                    54402 non-null  object
#  1   Département                54402 non-null  object
#  2   Agglomération              54402 non-null  object
#  3   Luminosité                 54402 non-null  object
#  4   Météo (conditions atmos.)  54391 non-null  object
#  5   Type de collision          54401 non-null  object
#  6   Catégorie de route         54402 non-null  object
#  7   Régime de circulation      54402 non-null  object
#  8   Nombre de voies            54402 non-null  object
#  9   État de la surface         54402 non-null  object
#  10  Infrastructure             54402 non-null  object
#  11  Situation de laccident    54402 non-null  object
#  12  Vitesse max autorisée      54402 non-null  object
#  13  Gravité (label)            54402 non-null  object
# dtypes: object(14)
# memory usage: 5.8+ MB

# %%
# Statistiques générales
df.describe()
# Out:
#          Num_Acc Département     Agglomération  Luminosité  \
# count      54402       54402             54402       54402
# unique         1         107                 2           5
# top     2,02E+11          75  En agglomération  Plein jour
# freq       54402        4191             34010       35580
#
#        Météo (conditions atmos.)          Type de collision  \
# count                      54391                      54401
# unique                         9                          8
# top                      Normale  2 véhicules - par le côté
# freq                       41791                      16371
#
#        Catégorie de route Régime de circulation Nombre de voies  \
# count               54402                 54402           54402
# unique                  8                     5              14
# top        Voie communale      Bidirectionnelle       2 voie(s)
# freq                22910                 33576           35076
#
#        État de la surface Infrastructure Situation de laccident  \
# count               54402          54402                   54402
# unique                 10             11                       7
# top               Normale          Aucun            Sur chaussée
# freq                42418          45698                   44782
#
#        Vitesse max autorisée Gravité (label)
# count                  54402           54402
# unique                    35               3
# top                  50 km/h    Blessé léger
# freq                   24497           34744

# %%
# Valeurs manquantes
df.isnull().sum()
# Out:
# Num_Acc                       0
# Département                   0
# Agglomération                 0
# Luminosité                    0
# Météo (conditions atmos.)    11
# Type de collision             1
# Catégorie de route            0
# Régime de circulation         0
# Nombre de voies               0
# État de la surface            0
# Infrastructure                0
# Situation de laccident       0
# Vitesse max autorisée         0
# Gravité (label)               0
# dtype: int64
